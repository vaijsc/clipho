# %%
import os
import json

folder_path = "../tmp/evaluation"

# %% [markdown]
# # Zeroshot Retrieval

# %% [markdown]
# ## Crossmodal3600

# %%
data_name = "crossmodal3600" 
model_name = "google_siglip2-base-patch16-256_no_dual_projection"
stage_name = "stage_1"

files = sorted([file for file in os.listdir(folder_path) if data_name in file and model_name in file and stage_name in file and "checkpoint" in file], key=lambda file: int(file.split("checkpoint-")[1].split("_hf")[0]))
files.extend([file for file in os.listdir(folder_path) if data_name in file and model_name in file and stage_name in file and "checkpoint" not in file])
print(len(files))

all_results = {}
for file in files:
    if "checkpoint" in file:
        checkpoint = int(file.split("checkpoint-")[1].split("_hf")[0])
    else:
        checkpoint = "final"

    with open(f"{folder_path}/{file}") as f:
        result = json.load(f)

    all_results[checkpoint] = result

all_top_k = [1, 5, 10]
best_results = {}

for k in all_top_k:
    text2image_recall = f"text2image_recall@{k}"
    image2text_recall = f"image2text_recall@{k}"

    best_results[text2image_recall] = []
    best_results[image2text_recall] = []

    for checkpoint, result in all_results.items():
        best_results[text2image_recall].append({"checkpoint": checkpoint, "result": result[text2image_recall]})
        best_results[image2text_recall].append({"checkpoint": checkpoint, "result": result[image2text_recall]})

    best_results[text2image_recall] = sorted(best_results[text2image_recall], key=lambda x: x["result"], reverse=True)[:5]
    best_results[image2text_recall] = sorted(best_results[image2text_recall], key=lambda x: x["result"], reverse=True)[:5]

for metric, top_results in best_results.items():
    print("##########"*3)
    print(f"Metric: {metric}")
    for i, best_result in enumerate(top_results):
        print(f"Best checkpoint {i+1}: {best_result['checkpoint']}")
        print(f"Best result {i+1}: {best_result['result']}")
        print(f"Other results:")
        print(all_results[best_result['checkpoint']]) 
        print()
# Out:
# 164
# ##############################
# Metric: text2image_recall@1
# Best checkpoint 1: 356
# Best result 1: 0.6725000143051147
# Other results:
# {'text2image_recall@1': 0.6725000143051147, 'image2text_recall@1': 0.659166693687439, 'text2image_recall@5': 0.8936111330986023, 'image2text_recall@5': 0.8974999785423279, 'text2image_recall@10': 0.9416666626930237, 'image2text_recall@10': 0.9397222399711609}
#
# Best checkpoint 2: 534
# Best result 2: 0.6708333492279053
# Other results:
# {'text2image_recall@1': 0.6708333492279053, 'image2text_recall@1': 0.6555555462837219, 'text2image_recall@5': 0.8911111354827881, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.941944420337677, 'image2text_recall@10': 0.9427777528762817}
#
# Best checkpoint 3: 267
# Best result 3: 0.6688888669013977
# Other results:
# {'text2image_recall@1': 0.6688888669013977, 'image2text_recall@1': 0.659166693687439, 'text2image_recall@5': 0.8869444727897644, 'image2text_recall@5': 0.8927778005599976, 'text2image_recall@10': 0.9391666650772095, 'image2text_recall@10': 0.9388889074325562}
#
# Best checkpoint 4: 445
# Best result 4: 0.668055534362793
# Other results:
# {'text2image_recall@1': 0.668055534362793, 'image2text_recall@1': 0.6572222113609314, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9416666626930237, 'image2text_recall@10': 0.9422222375869751}
#
# Best checkpoint 5: 623
# Best result 5: 0.6675000190734863
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6569444537162781, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9422222375869751, 'image2text_recall@10': 0.9441666603088379}
#
# ##############################
# Metric: image2text_recall@1
# Best checkpoint 1: 267
# Best result 1: 0.659166693687439
# Other results:
# {'text2image_recall@1': 0.6688888669013977, 'image2text_recall@1': 0.659166693687439, 'text2image_recall@5': 0.8869444727897644, 'image2text_recall@5': 0.8927778005599976, 'text2image_recall@10': 0.9391666650772095, 'image2text_recall@10': 0.9388889074325562}
#
# Best checkpoint 2: 356
# Best result 2: 0.659166693687439
# Other results:
# {'text2image_recall@1': 0.6725000143051147, 'image2text_recall@1': 0.659166693687439, 'text2image_recall@5': 0.8936111330986023, 'image2text_recall@5': 0.8974999785423279, 'text2image_recall@10': 0.9416666626930237, 'image2text_recall@10': 0.9397222399711609}
#
# Best checkpoint 3: 712
# Best result 3: 0.6588888764381409
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6588888764381409, 'text2image_recall@5': 0.8916666507720947, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.9436110854148865, 'image2text_recall@10': 0.9441666603088379}
#
# Best checkpoint 4: 445
# Best result 4: 0.6572222113609314
# Other results:
# {'text2image_recall@1': 0.668055534362793, 'image2text_recall@1': 0.6572222113609314, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9416666626930237, 'image2text_recall@10': 0.9422222375869751}
#
# Best checkpoint 5: 623
# Best result 5: 0.6569444537162781
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6569444537162781, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9422222375869751, 'image2text_recall@10': 0.9441666603088379}
#
# ##############################
# Metric: text2image_recall@5
# Best checkpoint 1: 979
# Best result 1: 0.8938888907432556
# Other results:
# {'text2image_recall@1': 0.6630555391311646, 'image2text_recall@1': 0.6547222137451172, 'text2image_recall@5': 0.8938888907432556, 'image2text_recall@5': 0.8955555558204651, 'text2image_recall@10': 0.940833330154419, 'image2text_recall@10': 0.941944420337677}
#
# Best checkpoint 2: 356
# Best result 2: 0.8936111330986023
# Other results:
# {'text2image_recall@1': 0.6725000143051147, 'image2text_recall@1': 0.659166693687439, 'text2image_recall@5': 0.8936111330986023, 'image2text_recall@5': 0.8974999785423279, 'text2image_recall@10': 0.9416666626930237, 'image2text_recall@10': 0.9397222399711609}
#
# Best checkpoint 3: 890
# Best result 3: 0.8936111330986023
# Other results:
# {'text2image_recall@1': 0.6650000214576721, 'image2text_recall@1': 0.6561111211776733, 'text2image_recall@5': 0.8936111330986023, 'image2text_recall@5': 0.8961111307144165, 'text2image_recall@10': 0.941944420337677, 'image2text_recall@10': 0.941944420337677}
#
# Best checkpoint 4: 801
# Best result 4: 0.8924999833106995
# Other results:
# {'text2image_recall@1': 0.6655555367469788, 'image2text_recall@1': 0.6558333039283752, 'text2image_recall@5': 0.8924999833106995, 'image2text_recall@5': 0.8963888883590698, 'text2image_recall@10': 0.9430555701255798, 'image2text_recall@10': 0.9422222375869751}
#
# Best checkpoint 5: 1068
# Best result 5: 0.8919444680213928
# Other results:
# {'text2image_recall@1': 0.6641666889190674, 'image2text_recall@1': 0.6530555486679077, 'text2image_recall@5': 0.8919444680213928, 'image2text_recall@5': 0.8947222232818604, 'text2image_recall@10': 0.9399999976158142, 'image2text_recall@10': 0.9422222375869751}
#
# ##############################
# Metric: image2text_recall@5
# Best checkpoint 1: 356
# Best result 1: 0.8974999785423279
# Other results:
# {'text2image_recall@1': 0.6725000143051147, 'image2text_recall@1': 0.659166693687439, 'text2image_recall@5': 0.8936111330986023, 'image2text_recall@5': 0.8974999785423279, 'text2image_recall@10': 0.9416666626930237, 'image2text_recall@10': 0.9397222399711609}
#
# Best checkpoint 2: 445
# Best result 2: 0.8972222208976746
# Other results:
# {'text2image_recall@1': 0.668055534362793, 'image2text_recall@1': 0.6572222113609314, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9416666626930237, 'image2text_recall@10': 0.9422222375869751}
#
# Best checkpoint 3: 623
# Best result 3: 0.8972222208976746
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6569444537162781, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9422222375869751, 'image2text_recall@10': 0.9441666603088379}
#
# Best checkpoint 4: 534
# Best result 4: 0.8966666460037231
# Other results:
# {'text2image_recall@1': 0.6708333492279053, 'image2text_recall@1': 0.6555555462837219, 'text2image_recall@5': 0.8911111354827881, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.941944420337677, 'image2text_recall@10': 0.9427777528762817}
#
# Best checkpoint 5: 712
# Best result 5: 0.8966666460037231
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6588888764381409, 'text2image_recall@5': 0.8916666507720947, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.9436110854148865, 'image2text_recall@10': 0.9441666603088379}
#
# ##############################
# Metric: text2image_recall@10
# Best checkpoint 1: 712
# Best result 1: 0.9436110854148865
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6588888764381409, 'text2image_recall@5': 0.8916666507720947, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.9436110854148865, 'image2text_recall@10': 0.9441666603088379}
#
# Best checkpoint 2: 801
# Best result 2: 0.9430555701255798
# Other results:
# {'text2image_recall@1': 0.6655555367469788, 'image2text_recall@1': 0.6558333039283752, 'text2image_recall@5': 0.8924999833106995, 'image2text_recall@5': 0.8963888883590698, 'text2image_recall@10': 0.9430555701255798, 'image2text_recall@10': 0.9422222375869751}
#
# Best checkpoint 3: 623
# Best result 3: 0.9422222375869751
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6569444537162781, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9422222375869751, 'image2text_recall@10': 0.9441666603088379}
#
# Best checkpoint 4: 534
# Best result 4: 0.941944420337677
# Other results:
# {'text2image_recall@1': 0.6708333492279053, 'image2text_recall@1': 0.6555555462837219, 'text2image_recall@5': 0.8911111354827881, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.941944420337677, 'image2text_recall@10': 0.9427777528762817}
#
# Best checkpoint 5: 890
# Best result 5: 0.941944420337677
# Other results:
# {'text2image_recall@1': 0.6650000214576721, 'image2text_recall@1': 0.6561111211776733, 'text2image_recall@5': 0.8936111330986023, 'image2text_recall@5': 0.8961111307144165, 'text2image_recall@10': 0.941944420337677, 'image2text_recall@10': 0.941944420337677}
#
# ##############################
# Metric: image2text_recall@10
# Best checkpoint 1: 623
# Best result 1: 0.9441666603088379
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6569444537162781, 'text2image_recall@5': 0.8913888931274414, 'image2text_recall@5': 0.8972222208976746, 'text2image_recall@10': 0.9422222375869751, 'image2text_recall@10': 0.9441666603088379}
#
# Best checkpoint 2: 712
# Best result 2: 0.9441666603088379
# Other results:
# {'text2image_recall@1': 0.6675000190734863, 'image2text_recall@1': 0.6588888764381409, 'text2image_recall@5': 0.8916666507720947, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.9436110854148865, 'image2text_recall@10': 0.9441666603088379}
#
# Best checkpoint 3: 1335
# Best result 3: 0.9430555701255798
# Other results:
# {'text2image_recall@1': 0.6633333563804626, 'image2text_recall@1': 0.648888885974884, 'text2image_recall@5': 0.8919444680213928, 'image2text_recall@5': 0.8941666483879089, 'text2image_recall@10': 0.9388889074325562, 'image2text_recall@10': 0.9430555701255798}
#
# Best checkpoint 4: 534
# Best result 4: 0.9427777528762817
# Other results:
# {'text2image_recall@1': 0.6708333492279053, 'image2text_recall@1': 0.6555555462837219, 'text2image_recall@5': 0.8911111354827881, 'image2text_recall@5': 0.8966666460037231, 'text2image_recall@10': 0.941944420337677, 'image2text_recall@10': 0.9427777528762817}
#
# Best checkpoint 5: 1246
# Best result 5: 0.9427777528762817
# Other results:
# {'text2image_recall@1': 0.6638888716697693, 'image2text_recall@1': 0.6519444584846497, 'text2image_recall@5': 0.8905555605888367, 'image2text_recall@5': 0.8936111330986023, 'text2image_recall@10': 0.9386110901832581, 'image2text_recall@10': 0.9427777528762817}

# %%
all_results[8900]
# Out:
# {'text2image_recall@1': 0.6461111307144165,
#  'image2text_recall@1': 0.6252777576446533,
#  'text2image_recall@5': 0.8838889002799988,
#  'image2text_recall@5': 0.8772222399711609,
#  'text2image_recall@10': 0.9350000023841858,
#  'image2text_recall@10': 0.9344444274902344}

# %% [markdown]
# ## KTVIC

# %%
data_name = "KTVIC" 
model_name = "google_siglip2-base-patch16-256_no_dual_projection"
stage_name = "stage_1"

files = sorted([file for file in os.listdir(folder_path) if data_name in file and model_name in file and stage_name in file and "checkpoint" in file], key=lambda file: int(file.split("checkpoint-")[1].split("_hf")[0]))
files.extend([file for file in os.listdir(folder_path) if data_name in file and model_name in file and stage_name in file and "checkpoint" not in file])
print(len(files))

all_results = {}
for file in files:
    if "checkpoint" in file:
        checkpoint = int(file.split("checkpoint-")[1].split("_hf")[0])
    else:
        checkpoint = "final"

    with open(f"{folder_path}/{file}") as f:
        result = json.load(f)

    all_results[checkpoint] = result

all_top_k = [1, 5, 10]
best_results = {}

for k in all_top_k:
    text2image_recall = f"text2image_recall@{k}"
    image2text_recall = f"image2text_recall@{k}"

    best_results[text2image_recall] = []
    best_results[image2text_recall] = []

    for checkpoint, result in all_results.items():
        best_results[text2image_recall].append({"checkpoint": checkpoint, "result": result[text2image_recall]})
        best_results[image2text_recall].append({"checkpoint": checkpoint, "result": result[image2text_recall]})

    best_results[text2image_recall] = sorted(best_results[text2image_recall], key=lambda x: x["result"], reverse=True)[:5]
    best_results[image2text_recall] = sorted(best_results[image2text_recall], key=lambda x: x["result"], reverse=True)[:5]

for metric, top_results in best_results.items():
    print("##########"*3)
    print(f"Metric: {metric}")
    for i, best_result in enumerate(top_results):
        print(f"Best checkpoint {i+1}: {best_result['checkpoint']}")
        print(f"Best result {i+1}: {best_result['result']}")
        print(f"Other results:")
        print(all_results[best_result['checkpoint']]) 
        print()
# Out:
# 164
# ##############################
# Metric: text2image_recall@1
# Best checkpoint 1: 890
# Best result 1: 0.35985663533210754
# Other results:
# {'text2image_recall@1': 0.35985663533210754, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.65663081407547, 'image2text_recall@5': 0.7150537371635437, 'text2image_recall@10': 0.7666666507720947, 'image2text_recall@10': 0.8046594858169556}
#
# Best checkpoint 2: 445
# Best result 2: 0.35949820280075073
# Other results:
# {'text2image_recall@1': 0.35949820280075073, 'image2text_recall@1': 0.4677419364452362, 'text2image_recall@5': 0.6519713401794434, 'image2text_recall@5': 0.698924720287323, 'text2image_recall@10': 0.7627240419387817, 'image2text_recall@10': 0.815412163734436}
#
# Best checkpoint 3: 1068
# Best result 3: 0.3584229350090027
# Other results:
# {'text2image_recall@1': 0.3584229350090027, 'image2text_recall@1': 0.46415770053863525, 'text2image_recall@5': 0.6544802784919739, 'image2text_recall@5': 0.7114695310592651, 'text2image_recall@10': 0.7641577124595642, 'image2text_recall@10': 0.8064516186714172}
#
# Best checkpoint 4: 801
# Best result 4: 0.3580645024776459
# Other results:
# {'text2image_recall@1': 0.3580645024776459, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.6616487503051758, 'image2text_recall@5': 0.7168458700180054, 'text2image_recall@10': 0.7663082480430603, 'image2text_recall@10': 0.8064516186714172}
#
# Best checkpoint 5: 1157
# Best result 5: 0.35770609974861145
# Other results:
# {'text2image_recall@1': 0.35770609974861145, 'image2text_recall@1': 0.45698925852775574, 'text2image_recall@5': 0.6544802784919739, 'image2text_recall@5': 0.7114695310592651, 'text2image_recall@10': 0.7663082480430603, 'image2text_recall@10': 0.8100358247756958}
#
# ##############################
# Metric: image2text_recall@1
# Best checkpoint 1: 89
# Best result 1: 0.4820788502693176
# Other results:
# {'text2image_recall@1': 0.3078853189945221, 'image2text_recall@1': 0.4820788502693176, 'text2image_recall@5': 0.5788530707359314, 'image2text_recall@5': 0.7204301357269287, 'text2image_recall@10': 0.6953405141830444, 'image2text_recall@10': 0.8279569745063782}
#
# Best checkpoint 2: 178
# Best result 2: 0.4784946143627167
# Other results:
# {'text2image_recall@1': 0.3397849500179291, 'image2text_recall@1': 0.4784946143627167, 'text2image_recall@5': 0.6405017971992493, 'image2text_recall@5': 0.7222222089767456, 'text2image_recall@10': 0.7469534277915955, 'image2text_recall@10': 0.8279569745063782}
#
# Best checkpoint 3: 267
# Best result 3: 0.47311827540397644
# Other results:
# {'text2image_recall@1': 0.3559139668941498, 'image2text_recall@1': 0.47311827540397644, 'text2image_recall@5': 0.647311806678772, 'image2text_recall@5': 0.7060931921005249, 'text2image_recall@10': 0.7584229111671448, 'image2text_recall@10': 0.8315412402153015}
#
# Best checkpoint 4: 801
# Best result 4: 0.4695340394973755
# Other results:
# {'text2image_recall@1': 0.3580645024776459, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.6616487503051758, 'image2text_recall@5': 0.7168458700180054, 'text2image_recall@10': 0.7663082480430603, 'image2text_recall@10': 0.8064516186714172}
#
# Best checkpoint 5: 890
# Best result 5: 0.4695340394973755
# Other results:
# {'text2image_recall@1': 0.35985663533210754, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.65663081407547, 'image2text_recall@5': 0.7150537371635437, 'text2image_recall@10': 0.7666666507720947, 'image2text_recall@10': 0.8046594858169556}
#
# ##############################
# Metric: text2image_recall@5
# Best checkpoint 1: 801
# Best result 1: 0.6616487503051758
# Other results:
# {'text2image_recall@1': 0.3580645024776459, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.6616487503051758, 'image2text_recall@5': 0.7168458700180054, 'text2image_recall@10': 0.7663082480430603, 'image2text_recall@10': 0.8064516186714172}
#
# Best checkpoint 2: 712
# Best result 2: 0.657706081867218
# Other results:
# {'text2image_recall@1': 0.3562723994255066, 'image2text_recall@1': 0.45698925852775574, 'text2image_recall@5': 0.657706081867218, 'image2text_recall@5': 0.7078853249549866, 'text2image_recall@10': 0.7677419185638428, 'image2text_recall@10': 0.8028674125671387}
#
# Best checkpoint 3: 623
# Best result 3: 0.65663081407547
# Other results:
# {'text2image_recall@1': 0.35483869910240173, 'image2text_recall@1': 0.4605734646320343, 'text2image_recall@5': 0.65663081407547, 'image2text_recall@5': 0.7096773982048035, 'text2image_recall@10': 0.7688171863555908, 'image2text_recall@10': 0.815412163734436}
#
# Best checkpoint 4: 890
# Best result 4: 0.65663081407547
# Other results:
# {'text2image_recall@1': 0.35985663533210754, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.65663081407547, 'image2text_recall@5': 0.7150537371635437, 'text2image_recall@10': 0.7666666507720947, 'image2text_recall@10': 0.8046594858169556}
#
# Best checkpoint 5: 979
# Best result 5: 0.6548386812210083
# Other results:
# {'text2image_recall@1': 0.35519713163375854, 'image2text_recall@1': 0.4659498333930969, 'text2image_recall@5': 0.6548386812210083, 'image2text_recall@5': 0.7204301357269287, 'text2image_recall@10': 0.7641577124595642, 'image2text_recall@10': 0.8082437515258789}
#
# ##############################
# Metric: image2text_recall@5
# Best checkpoint 1: 178
# Best result 1: 0.7222222089767456
# Other results:
# {'text2image_recall@1': 0.3397849500179291, 'image2text_recall@1': 0.4784946143627167, 'text2image_recall@5': 0.6405017971992493, 'image2text_recall@5': 0.7222222089767456, 'text2image_recall@10': 0.7469534277915955, 'image2text_recall@10': 0.8279569745063782}
#
# Best checkpoint 2: 89
# Best result 2: 0.7204301357269287
# Other results:
# {'text2image_recall@1': 0.3078853189945221, 'image2text_recall@1': 0.4820788502693176, 'text2image_recall@5': 0.5788530707359314, 'image2text_recall@5': 0.7204301357269287, 'text2image_recall@10': 0.6953405141830444, 'image2text_recall@10': 0.8279569745063782}
#
# Best checkpoint 3: 979
# Best result 3: 0.7204301357269287
# Other results:
# {'text2image_recall@1': 0.35519713163375854, 'image2text_recall@1': 0.4659498333930969, 'text2image_recall@5': 0.6548386812210083, 'image2text_recall@5': 0.7204301357269287, 'text2image_recall@10': 0.7641577124595642, 'image2text_recall@10': 0.8082437515258789}
#
# Best checkpoint 4: 801
# Best result 4: 0.7168458700180054
# Other results:
# {'text2image_recall@1': 0.3580645024776459, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.6616487503051758, 'image2text_recall@5': 0.7168458700180054, 'text2image_recall@10': 0.7663082480430603, 'image2text_recall@10': 0.8064516186714172}
#
# Best checkpoint 5: 534
# Best result 5: 0.7150537371635437
# Other results:
# {'text2image_recall@1': 0.35519713163375854, 'image2text_recall@1': 0.4659498333930969, 'text2image_recall@5': 0.6534050107002258, 'image2text_recall@5': 0.7150537371635437, 'text2image_recall@10': 0.7688171863555908, 'image2text_recall@10': 0.815412163734436}
#
# ##############################
# Metric: text2image_recall@10
# Best checkpoint 1: 534
# Best result 1: 0.7688171863555908
# Other results:
# {'text2image_recall@1': 0.35519713163375854, 'image2text_recall@1': 0.4659498333930969, 'text2image_recall@5': 0.6534050107002258, 'image2text_recall@5': 0.7150537371635437, 'text2image_recall@10': 0.7688171863555908, 'image2text_recall@10': 0.815412163734436}
#
# Best checkpoint 2: 623
# Best result 2: 0.7688171863555908
# Other results:
# {'text2image_recall@1': 0.35483869910240173, 'image2text_recall@1': 0.4605734646320343, 'text2image_recall@5': 0.65663081407547, 'image2text_recall@5': 0.7096773982048035, 'text2image_recall@10': 0.7688171863555908, 'image2text_recall@10': 0.815412163734436}
#
# Best checkpoint 3: 712
# Best result 3: 0.7677419185638428
# Other results:
# {'text2image_recall@1': 0.3562723994255066, 'image2text_recall@1': 0.45698925852775574, 'text2image_recall@5': 0.657706081867218, 'image2text_recall@5': 0.7078853249549866, 'text2image_recall@10': 0.7677419185638428, 'image2text_recall@10': 0.8028674125671387}
#
# Best checkpoint 4: 890
# Best result 4: 0.7666666507720947
# Other results:
# {'text2image_recall@1': 0.35985663533210754, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.65663081407547, 'image2text_recall@5': 0.7150537371635437, 'text2image_recall@10': 0.7666666507720947, 'image2text_recall@10': 0.8046594858169556}
#
# Best checkpoint 5: 801
# Best result 5: 0.7663082480430603
# Other results:
# {'text2image_recall@1': 0.3580645024776459, 'image2text_recall@1': 0.4695340394973755, 'text2image_recall@5': 0.6616487503051758, 'image2text_recall@5': 0.7168458700180054, 'text2image_recall@10': 0.7663082480430603, 'image2text_recall@10': 0.8064516186714172}
#
# ##############################
# Metric: image2text_recall@10
# Best checkpoint 1: 267
# Best result 1: 0.8315412402153015
# Other results:
# {'text2image_recall@1': 0.3559139668941498, 'image2text_recall@1': 0.47311827540397644, 'text2image_recall@5': 0.647311806678772, 'image2text_recall@5': 0.7060931921005249, 'text2image_recall@10': 0.7584229111671448, 'image2text_recall@10': 0.8315412402153015}
#
# Best checkpoint 2: 89
# Best result 2: 0.8279569745063782
# Other results:
# {'text2image_recall@1': 0.3078853189945221, 'image2text_recall@1': 0.4820788502693176, 'text2image_recall@5': 0.5788530707359314, 'image2text_recall@5': 0.7204301357269287, 'text2image_recall@10': 0.6953405141830444, 'image2text_recall@10': 0.8279569745063782}
#
# Best checkpoint 3: 178
# Best result 3: 0.8279569745063782
# Other results:
# {'text2image_recall@1': 0.3397849500179291, 'image2text_recall@1': 0.4784946143627167, 'text2image_recall@5': 0.6405017971992493, 'image2text_recall@5': 0.7222222089767456, 'text2image_recall@10': 0.7469534277915955, 'image2text_recall@10': 0.8279569745063782}
#
# Best checkpoint 4: 356
# Best result 4: 0.8189964294433594
# Other results:
# {'text2image_recall@1': 0.3566308319568634, 'image2text_recall@1': 0.4677419364452362, 'text2image_recall@5': 0.6512544751167297, 'image2text_recall@5': 0.6971325874328613, 'text2image_recall@10': 0.7609319090843201, 'image2text_recall@10': 0.8189964294433594}
#
# Best checkpoint 5: 445
# Best result 5: 0.815412163734436
# Other results:
# {'text2image_recall@1': 0.35949820280075073, 'image2text_recall@1': 0.4677419364452362, 'text2image_recall@5': 0.6519713401794434, 'image2text_recall@5': 0.698924720287323, 'text2image_recall@10': 0.7627240419387817, 'image2text_recall@10': 0.815412163734436}

# %% [markdown]
# # Zeroshot Classification

# %% [markdown]
# ## 30VNFoods_test

# %%
data_name = "30VNFoods_test" 
model_name = "google_siglip2-base-patch16-256_no_dual_projection"
stage_name = "stage_1"

files = sorted([file for file in os.listdir(folder_path) if data_name in file and model_name in file and stage_name in file and "checkpoint" in file], key=lambda file: int(file.split("checkpoint-")[1].split("_hf")[0]))
files.extend([file for file in os.listdir(folder_path) if data_name in file and model_name in file and stage_name in file and "checkpoint" not in file])
print(len(files))

all_results = {}
for file in files:
    if "checkpoint" in file:
        checkpoint = int(file.split("checkpoint-")[1].split("_hf")[0])
    else:
        checkpoint = "final"

    with open(f"{folder_path}/{file}") as f:
        result = json.load(f)

    all_results[checkpoint] = result

metrics = ["acc1", "acc5", "mean_per_class_recall"]
best_results = {}

for metric in metrics:
    best_results[metric] = []

    for checkpoint, result in all_results.items():
        best_results[metric].append({"checkpoint": checkpoint, "result": result[metric]})

    best_results[metric] = sorted(best_results[metric], key=lambda x: x["result"], reverse=True)[0: 10]

for metric, top_results in best_results.items():
    print("##########"*3)
    print(f"Metric: {metric}")
    for i, best_result in enumerate(top_results):
        print(f"Best checkpoint {i+1}: {best_result['checkpoint']}")
        print(f"Best result {i+1}: {best_result['result']}")
        print(f"Other results:")
        print(all_results[best_result['checkpoint']]) 
        print()
# Out:
# 164
# ##############################
# Metric: acc1
# Best checkpoint 1: 267
# Best result 1: 0.7365079365079366
# Other results:
# {'acc1': 0.7365079365079366, 'acc5': 0.9674603174603175, 'mean_per_class_recall': 0.7254963482747921}
#
# Best checkpoint 2: 178
# Best result 2: 0.7357142857142858
# Other results:
# {'acc1': 0.7357142857142858, 'acc5': 0.9698412698412698, 'mean_per_class_recall': 0.7228467367116095}
#
# Best checkpoint 3: 445
# Best result 3: 0.7353174603174604
# Other results:
# {'acc1': 0.7353174603174604, 'acc5': 0.9678571428571429, 'mean_per_class_recall': 0.7258659825549283}
#
# Best checkpoint 4: 356
# Best result 4: 0.7351190476190477
# Other results:
# {'acc1': 0.7351190476190477, 'acc5': 0.9678571428571429, 'mean_per_class_recall': 0.724580270596356}
#
# Best checkpoint 5: 89
# Best result 5: 0.7339285714285714
# Other results:
# {'acc1': 0.7339285714285714, 'acc5': 0.9670634920634921, 'mean_per_class_recall': 0.7197667001838898}
#
# Best checkpoint 6: 534
# Best result 6: 0.7325396825396825
# Other results:
# {'acc1': 0.7325396825396825, 'acc5': 0.969047619047619, 'mean_per_class_recall': 0.7226859264384043}
#
# Best checkpoint 7: 623
# Best result 7: 0.7325396825396825
# Other results:
# {'acc1': 0.7325396825396825, 'acc5': 0.969047619047619, 'mean_per_class_recall': 0.722827272666343}
#
# Best checkpoint 8: 801
# Best result 8: 0.7307539682539682
# Other results:
# {'acc1': 0.7307539682539682, 'acc5': 0.9682539682539683, 'mean_per_class_recall': 0.7202597880931247}
#
# Best checkpoint 9: 890
# Best result 9: 0.7305555555555555
# Other results:
# {'acc1': 0.7305555555555555, 'acc5': 0.9680555555555556, 'mean_per_class_recall': 0.7201237238987364}
#
# Best checkpoint 10: 712
# Best result 10: 0.7299603174603174
# Other results:
# {'acc1': 0.7299603174603174, 'acc5': 0.968452380952381, 'mean_per_class_recall': 0.7200182320778344}
#
# ##############################
# Metric: acc5
# Best checkpoint 1: 178
# Best result 1: 0.9698412698412698
# Other results:
# {'acc1': 0.7357142857142858, 'acc5': 0.9698412698412698, 'mean_per_class_recall': 0.7228467367116095}
#
# Best checkpoint 2: 534
# Best result 2: 0.969047619047619
# Other results:
# {'acc1': 0.7325396825396825, 'acc5': 0.969047619047619, 'mean_per_class_recall': 0.7226859264384043}
#
# Best checkpoint 3: 623
# Best result 3: 0.969047619047619
# Other results:
# {'acc1': 0.7325396825396825, 'acc5': 0.969047619047619, 'mean_per_class_recall': 0.722827272666343}
#
# Best checkpoint 4: 712
# Best result 4: 0.968452380952381
# Other results:
# {'acc1': 0.7299603174603174, 'acc5': 0.968452380952381, 'mean_per_class_recall': 0.7200182320778344}
#
# Best checkpoint 5: 801
# Best result 5: 0.9682539682539683
# Other results:
# {'acc1': 0.7307539682539682, 'acc5': 0.9682539682539683, 'mean_per_class_recall': 0.7202597880931247}
#
# Best checkpoint 6: 890
# Best result 6: 0.9680555555555556
# Other results:
# {'acc1': 0.7305555555555555, 'acc5': 0.9680555555555556, 'mean_per_class_recall': 0.7201237238987364}
#
# Best checkpoint 7: 356
# Best result 7: 0.9678571428571429
# Other results:
# {'acc1': 0.7351190476190477, 'acc5': 0.9678571428571429, 'mean_per_class_recall': 0.724580270596356}
#
# Best checkpoint 8: 445
# Best result 8: 0.9678571428571429
# Other results:
# {'acc1': 0.7353174603174604, 'acc5': 0.9678571428571429, 'mean_per_class_recall': 0.7258659825549283}
#
# Best checkpoint 9: 267
# Best result 9: 0.9674603174603175
# Other results:
# {'acc1': 0.7365079365079366, 'acc5': 0.9674603174603175, 'mean_per_class_recall': 0.7254963482747921}
#
# Best checkpoint 10: 89
# Best result 10: 0.9670634920634921
# Other results:
# {'acc1': 0.7339285714285714, 'acc5': 0.9670634920634921, 'mean_per_class_recall': 0.7197667001838898}
#
# ##############################
# Metric: mean_per_class_recall
# Best checkpoint 1: 445
# Best result 1: 0.7258659825549283
# Other results:
# {'acc1': 0.7353174603174604, 'acc5': 0.9678571428571429, 'mean_per_class_recall': 0.7258659825549283}
#
# Best checkpoint 2: 267
# Best result 2: 0.7254963482747921
# Other results:
# {'acc1': 0.7365079365079366, 'acc5': 0.9674603174603175, 'mean_per_class_recall': 0.7254963482747921}
#
# Best checkpoint 3: 356
# Best result 3: 0.724580270596356
# Other results:
# {'acc1': 0.7351190476190477, 'acc5': 0.9678571428571429, 'mean_per_class_recall': 0.724580270596356}
#
# Best checkpoint 4: 178
# Best result 4: 0.7228467367116095
# Other results:
# {'acc1': 0.7357142857142858, 'acc5': 0.9698412698412698, 'mean_per_class_recall': 0.7228467367116095}
#
# Best checkpoint 5: 623
# Best result 5: 0.722827272666343
# Other results:
# {'acc1': 0.7325396825396825, 'acc5': 0.969047619047619, 'mean_per_class_recall': 0.722827272666343}
#
# Best checkpoint 6: 534
# Best result 6: 0.7226859264384043
# Other results:
# {'acc1': 0.7325396825396825, 'acc5': 0.969047619047619, 'mean_per_class_recall': 0.7226859264384043}
#
# Best checkpoint 7: 801
# Best result 7: 0.7202597880931247
# Other results:
# {'acc1': 0.7307539682539682, 'acc5': 0.9682539682539683, 'mean_per_class_recall': 0.7202597880931247}
#
# Best checkpoint 8: 890
# Best result 8: 0.7201237238987364
# Other results:
# {'acc1': 0.7305555555555555, 'acc5': 0.9680555555555556, 'mean_per_class_recall': 0.7201237238987364}
#
# Best checkpoint 9: 712
# Best result 9: 0.7200182320778344
# Other results:
# {'acc1': 0.7299603174603174, 'acc5': 0.968452380952381, 'mean_per_class_recall': 0.7200182320778344}
#
# Best checkpoint 10: 89
# Best result 10: 0.7197667001838898
# Other results:
# {'acc1': 0.7339285714285714, 'acc5': 0.9670634920634921, 'mean_per_class_recall': 0.7197667001838898}
